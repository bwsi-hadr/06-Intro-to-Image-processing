# %% [markdown]
# <a href="https://colab.research.google.com/github/bwsi-hadr/06-Intro-to-Image-processing/blob/master/strohs_initial_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # System setup for BWSI Remote Sensing for HADR course
# This notebook will run through the initial setup of the development environment. It installs necessary packages, and configures the relevant settings. To run code, first click on a cell to highlight it, then use Ctrl+Enter, or click on the play button on the left to run the code within it. To run the code and advance to the next cell, press Shift+Enter.

# %% [markdown]
# ## Update system package manager and install dependencies
#
# ---
# The colab notebooks run the code on a remote virtual machine on Google cloud. The first time you use colab, only the default packages and programs are installed, so we need to do some installations to get up and running.
#
# ### Running system commands
#
# Typically, colab (jupyter) notebooks interact only the with the `python` kernel; that is, all of the code written into the cells are python commands, and are executed by the `python` interpreter program when the cell is run.
#
# However, we need to install system-level packages, which need to be run outside of `python`.  Fortunately, you are able to run command-line (the command line, or terminal, is a text-based interface to a computer) commands from jupyter/colab notebooks using the special `!` leading character. For example `!ls` runs the program `ls`, which _lists_ the contents of the current folder.

# %%
# !ls
# Out:
# sample_data

# %% [markdown]
# Additionally, the vm that hosts colab is _ephermeral_ which means that each time you disconnect, all your files and variables are deleted. In order to persist files, you can _mount_ (attach) your google drive folder, which will be accessible in the filesystem at `/content/drive/'My Drive'`
#
# This way, if you save a file to that directory, then it will persist between sessions.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/'My Drive'/*.ipynb
# Out:
# ls: cannot access '/content/drive/My Drive/*.ipynb': No such file or directory

# %% [markdown]
# ### Installing system packages with `apt`
# We will use this to run some terminal commands to install necessary packages using `apt`.
#
# `apt` is the built-in system package manager (kind of like a command-line app store). This allows us to install system programs from the command line into the virtual machine. In this first cell, we run the follow commands:
#
# `!apt update` (updates `apt` so that it knows about the latest versions of all packages)
# `!apt upgrade` (upgrades existing packages which have newer versions)
# `!apt install gdal-bin python-gdal python3-gdal` (installs three packages: `gdal-bin`, `python-gdal`, `python3-gdal`)
#
# The program [GDAL](https://gdal.org/) is an open source library of tools which can be used to process geospatial data. The packages we installed via `apt` are:
# - `gdal-bin` the main gdal program
# - `python-gdal` tools for integrating gdal with python
# - `python3-gdal` tools for integrating gdal with python3

# %%
# !apt update
# !apt upgrade
# !apt install gdal-bin python-gdal python3-gdal
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:2 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:11 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ Packages [62.1 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:15 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,663 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [580 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [725 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [4,172 B]
# Get:19 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [798 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [7,235 B]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [889 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1,245 kB]
# Fetched 6,245 kB in 41s (150 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 47 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Calculating upgrade... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   r-cran-brew r-cran-commonmark r-cran-praise r-cran-roxygen2 r-cran-testthat
# The following packages have been kept back:
#   libcudnn7 libcudnn7-dev libnccl-dev libnccl2
# The following packages will be upgraded:
#   base-files bash bzip2 libbz2-1.0 libbz2-dev libdevmapper1.02.1 libglib2.0-0
#   libglib2.0-bin libglib2.0-data libglib2.0-dev libglib2.0-dev-bin libnss3
#   libpam-systemd libssl-dev libssl1.1 libsystemd0 libudev1 libwavpack1
#   libzmq3-dev libzmq5 openssl r-base r-base-core r-base-dev r-cran-boot
#   r-cran-callr r-cran-devtools r-cran-digest r-cran-dplyr r-cran-ellipsis
#   r-cran-git2r r-cran-haven r-cran-hms r-cran-pillar r-cran-processx
#   r-cran-rmarkdown r-cran-usethis r-cran-vctrs r-recommended systemd
#   systemd-sysv tzdata udev
# 43 upgraded, 5 newly installed, 0 to remove and 4 not upgraded.
# Need to get 48.8 MB of archives.
# After this operation, 4,720 kB of additional disk space will be used.
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ r-base-core 3.6.1-1bionic [24.7 MB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 base-files amd64 10.1ubuntu2.5 [60.2 kB]
# Get:3 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-boot all 1.3-23-1cran1ppabionic0 [621 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 bash amd64 4.4.18-2ubuntu1.2 [614 kB]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ r-base 3.6.1-1bionic [42.5 kB]
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ r-recommended 3.6.1-1bionic [2,780 B]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ r-base-dev 3.6.1-1bionic [4,480 B]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 systemd-sysv amd64 237-3ubuntu10.24 [11.4 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpam-systemd amd64 237-3ubuntu10.24 [108 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsystemd0 amd64 237-3ubuntu10.24 [204 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 systemd amd64 237-3ubuntu10.24 [2,903 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 udev amd64 237-3ubuntu10.24 [1,101 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libudev1 amd64 237-3ubuntu10.24 [53.6 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libbz2-dev amd64 1.0.6-8.1ubuntu0.2 [30.0 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 bzip2 amd64 1.0.6-8.1ubuntu0.2 [33.9 kB]
# Get:16 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-brew all 1.0-6-3cran2ppa0bionic0 [70.2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libbz2-1.0 amd64 1.0.6-8.1ubuntu0.2 [31.2 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdevmapper1.02.1 amd64 2:1.02.145-4.1ubuntu3.18.04.1 [127 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglib2.0-dev amd64 2.56.4-0ubuntu0.18.04.4 [1,385 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglib2.0-dev-bin amd64 2.56.4-0ubuntu0.18.04.4 [102 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglib2.0-data all 2.56.4-0ubuntu0.18.04.4 [4,496 B]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglib2.0-bin amd64 2.56.4-0ubuntu0.18.04.4 [68.7 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglib2.0-0 amd64 2.56.4-0ubuntu0.18.04.4 [1,169 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libssl-dev amd64 1.1.1-1ubuntu2.1~18.04.4 [1,566 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libssl1.1 amd64 1.1.1-1ubuntu2.1~18.04.4 [1,300 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openssl amd64 1.1.1-1ubuntu2.1~18.04.4 [613 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 tzdata all 2019b-0ubuntu0.18.04 [190 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnss3 amd64 2:3.35-2ubuntu2.3 [1,136 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwavpack1 amd64 5.1.0-2ubuntu1.4 [76.6 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libzmq3-dev amd64 4.2.5-1ubuntu0.2 [400 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libzmq5 amd64 4.2.5-1ubuntu0.2 [221 kB]
# Get:32 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-processx amd64 3.4.0-1cran1ppabionic0 [234 kB]
# Get:33 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-callr all 3.3.0-1cran1ppabionic0 [306 kB]
# Get:34 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-commonmark amd64 1.7-1cran1ppabionic0 [119 kB]
# Get:35 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-git2r amd64 0.26.1-1cran1ppabionic0 [761 kB]
# Get:36 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-usethis all 1.5.1-1cran1ppabionic0 [897 kB]
# Get:37 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-digest amd64 0.6.20-1cran1ppabionic0 [153 kB]
# Get:38 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-roxygen2 amd64 6.1.1-1cran1ppabionic0 [457 kB]
# Get:39 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-praise all 1.0.0-3cran2ubuntu1~ubuntu18.04.1~ppa1 [17.4 kB]
# Get:40 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-testthat amd64 2.1.1-1cran1ppabionic0 [1,022 kB]
# Get:41 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-devtools all 2.1.0-1cran1ppabionic0 [310 kB]
# Get:42 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-dplyr amd64 0.8.3-1cran1ppabionic0 [1,739 kB]
# Get:43 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-ellipsis amd64 0.2.0.1-1cran1ppabionic0 [29.3 kB]
# Get:44 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-vctrs amd64 0.2.0-1cran1ppabionic0 [696 kB]
# Get:45 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-hms all 0.5.0-1cran1ppabionic0 [106 kB]
# Get:46 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-haven amd64 2.1.1-1cran1ppabionic0 [275 kB]
# Get:47 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-pillar all 1.4.2-1cran1ppabionic0 [176 kB]
# Get:48 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-rmarkdown all 1.14-1cran1ppabionic0 [2,582 kB]
# Fetched 48.8 MB in 15s (3,321 kB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# (Reading database ... 130963 files and directories currently installed.)
# Preparing to unpack .../base-files_10.1ubuntu2.5_amd64.deb ...
# Unpacking base-files (10.1ubuntu2.5) over (10.1ubuntu2.4) ...
# Setting up base-files (10.1ubuntu2.5) ...
# (Reading database ... 130963 files and directories currently installed.)
# Preparing to unpack .../bash_4.4.18-2ubuntu1.2_amd64.deb ...
# Unpacking bash (4.4.18-2ubuntu1.2) over (4.4.18-2ubuntu1.1) ...
# Setting up bash (4.4.18-2ubuntu1.2) ...
# update-alternatives: using /usr/share/man/man7/bash-builtins.7.gz to provide /usr/share/man/man7/builtins.7.gz (builtins.7.gz) in auto mode
# (Reading database ... 130963 files and directories currently installed.)
# Preparing to unpack .../systemd-sysv_237-3ubuntu10.24_amd64.deb ...
# Unpacking systemd-sysv (237-3ubuntu10.24) over (237-3ubuntu10.23) ...
# Preparing to unpack .../libpam-systemd_237-3ubuntu10.24_amd64.deb ...
# Unpacking libpam-systemd:amd64 (237-3ubuntu10.24) over (237-3ubuntu10.23) ...
# Preparing to unpack .../libsystemd0_237-3ubuntu10.24_amd64.deb ...
# Unpacking libsystemd0:amd64 (237-3ubuntu10.24) over (237-3ubuntu10.23) ...
# Setting up libsystemd0:amd64 (237-3ubuntu10.24) ...
# (Reading database ... 130963 files and directories currently installed.)
# Preparing to unpack .../systemd_237-3ubuntu10.24_amd64.deb ...
# Unpacking systemd (237-3ubuntu10.24) over (237-3ubuntu10.23) ...
# Preparing to unpack .../udev_237-3ubuntu10.24_amd64.deb ...
# Unpacking udev (237-3ubuntu10.24) over (237-3ubuntu10.23) ...
# Preparing to unpack .../libudev1_237-3ubuntu10.24_amd64.deb ...
# Unpacking libudev1:amd64 (237-3ubuntu10.24) over (237-3ubuntu10.23) ...
# Setting up libudev1:amd64 (237-3ubuntu10.24) ...
# (Reading database ... 130963 files and directories currently installed.)
# Preparing to unpack .../libbz2-dev_1.0.6-8.1ubuntu0.2_amd64.deb ...
# Unpacking libbz2-dev:amd64 (1.0.6-8.1ubuntu0.2) over (1.0.6-8.1ubuntu0.1) ...
# Preparing to unpack .../bzip2_1.0.6-8.1ubuntu0.2_amd64.deb ...
# Unpacking bzip2 (1.0.6-8.1ubuntu0.2) over (1.0.6-8.1ubuntu0.1) ...
# Preparing to unpack .../libbz2-1.0_1.0.6-8.1ubuntu0.2_amd64.deb ...
# Unpacking libbz2-1.0:amd64 (1.0.6-8.1ubuntu0.2) over (1.0.6-8.1ubuntu0.1) ...
# Setting up libbz2-1.0:amd64 (1.0.6-8.1ubuntu0.2) ...
# (Reading database ... 130963 files and directories currently installed.)
# Preparing to unpack .../00-libdevmapper1.02.1_2%3a1.02.145-4.1ubuntu3.18.04.1_amd64.deb ...
# Unpacking libdevmapper1.02.1:amd64 (2:1.02.145-4.1ubuntu3.18.04.1) over (2:1.02.145-4.1ubuntu3) ...
# Preparing to unpack .../01-libglib2.0-dev_2.56.4-0ubuntu0.18.04.4_amd64.deb ...
# Unpacking libglib2.0-dev:amd64 (2.56.4-0ubuntu0.18.04.4) over (2.56.4-0ubuntu0.18.04.3) ...
# Preparing to unpack .../02-libglib2.0-dev-bin_2.56.4-0ubuntu0.18.04.4_amd64.deb ...
# Unpacking libglib2.0-dev-bin (2.56.4-0ubuntu0.18.04.4) over (2.56.4-0ubuntu0.18.04.3) ...
# Preparing to unpack .../03-libglib2.0-data_2.56.4-0ubuntu0.18.04.4_all.deb ...
# Unpacking libglib2.0-data (2.56.4-0ubuntu0.18.04.4) over (2.56.4-0ubuntu0.18.04.3) ...
# Preparing to unpack .../04-libglib2.0-bin_2.56.4-0ubuntu0.18.04.4_amd64.deb ...
# Unpacking libglib2.0-bin (2.56.4-0ubuntu0.18.04.4) over (2.56.4-0ubuntu0.18.04.3) ...
# Preparing to unpack .../05-libglib2.0-0_2.56.4-0ubuntu0.18.04.4_amd64.deb ...
# Unpacking libglib2.0-0:amd64 (2.56.4-0ubuntu0.18.04.4) over (2.56.4-0ubuntu0.18.04.3) ...
# Preparing to unpack .../06-libssl-dev_1.1.1-1ubuntu2.1~18.04.4_amd64.deb ...
# Unpacking libssl-dev:amd64 (1.1.1-1ubuntu2.1~18.04.4) over (1.1.1-1ubuntu2.1~18.04.3) ...
# Preparing to unpack .../07-libssl1.1_1.1.1-1ubuntu2.1~18.04.4_amd64.deb ...
# Unpacking libssl1.1:amd64 (1.1.1-1ubuntu2.1~18.04.4) over (1.1.1-1ubuntu2.1~18.04.3) ...
# Preparing to unpack .../08-openssl_1.1.1-1ubuntu2.1~18.04.4_amd64.deb ...
# Unpacking openssl (1.1.1-1ubuntu2.1~18.04.4) over (1.1.1-1ubuntu2.1~18.04.3) ...
# Preparing to unpack .../09-tzdata_2019b-0ubuntu0.18.04_all.deb ...
# Unpacking tzdata (2019b-0ubuntu0.18.04) over (2019a-0ubuntu0.18.04) ...
# Preparing to unpack .../10-libnss3_2%3a3.35-2ubuntu2.3_amd64.deb ...
# Unpacking libnss3:amd64 (2:3.35-2ubuntu2.3) over (2:3.35-2ubuntu2.2) ...
# Preparing to unpack .../11-libwavpack1_5.1.0-2ubuntu1.4_amd64.deb ...
# Unpacking libwavpack1:amd64 (5.1.0-2ubuntu1.4) over (5.1.0-2ubuntu1.3) ...
# Preparing to unpack .../12-libzmq3-dev_4.2.5-1ubuntu0.2_amd64.deb ...
# Unpacking libzmq3-dev:amd64 (4.2.5-1ubuntu0.2) over (4.2.5-1ubuntu0.1) ...
# Preparing to unpack .../13-libzmq5_4.2.5-1ubuntu0.2_amd64.deb ...
# Unpacking libzmq5:amd64 (4.2.5-1ubuntu0.2) over (4.2.5-1ubuntu0.1) ...
# Preparing to unpack .../14-r-base-core_3.6.1-1bionic_amd64.deb ...
# Unpacking r-base-core (3.6.1-1bionic) over (3.6.0-2bionic) ...
# Preparing to unpack .../15-r-cran-boot_1.3-23-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-boot (1.3-23-1cran1ppabionic0) over (1.3-22-1cran1ppabionic0) ...
# Preparing to unpack .../16-r-base_3.6.1-1bionic_all.deb ...
# Unpacking r-base (3.6.1-1bionic) over (3.6.0-2bionic) ...
# Preparing to unpack .../17-r-recommended_3.6.1-1bionic_all.deb ...
# Unpacking r-recommended (3.6.1-1bionic) over (3.6.0-2bionic) ...
# Preparing to unpack .../18-r-base-dev_3.6.1-1bionic_all.deb ...
# Unpacking r-base-dev (3.6.1-1bionic) over (3.6.0-2bionic) ...
# Selecting previously unselected package r-cran-brew.
# Preparing to unpack .../19-r-cran-brew_1.0-6-3cran2ppa0bionic0_all.deb ...
# Unpacking r-cran-brew (1.0-6-3cran2ppa0bionic0) ...
# Preparing to unpack .../20-r-cran-processx_3.4.0-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-processx (3.4.0-1cran1ppabionic0) over (3.3.1-1cran1ppabionic0) ...
# Preparing to unpack .../21-r-cran-callr_3.3.0-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-callr (3.3.0-1cran1ppabionic0) over (3.2.0-1cran1ppabionic0) ...
# Selecting previously unselected package r-cran-commonmark.
# Preparing to unpack .../22-r-cran-commonmark_1.7-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-commonmark (1.7-1cran1ppabionic0) ...
# Preparing to unpack .../23-r-cran-git2r_0.26.1-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-git2r (0.26.1-1cran1ppabionic0) over (0.26.0-1cran1ppabionic0) ...
# Preparing to unpack .../24-r-cran-usethis_1.5.1-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-usethis (1.5.1-1cran1ppabionic0) over (1.5.0-1cran1ppabionic0) ...
# Preparing to unpack .../25-r-cran-digest_0.6.20-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-digest (0.6.20-1cran1ppabionic0) over (0.6.19-1cran1ppabionic0) ...
# Selecting previously unselected package r-cran-roxygen2.
# Preparing to unpack .../26-r-cran-roxygen2_6.1.1-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-roxygen2 (6.1.1-1cran1ppabionic0) ...
# Selecting previously unselected package r-cran-praise.
# Preparing to unpack .../27-r-cran-praise_1.0.0-3cran2ubuntu1~ubuntu18.04.1~ppa1_all.deb ...
# Unpacking r-cran-praise (1.0.0-3cran2ubuntu1~ubuntu18.04.1~ppa1) ...
# Selecting previously unselected package r-cran-testthat.
# Preparing to unpack .../28-r-cran-testthat_2.1.1-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-testthat (2.1.1-1cran1ppabionic0) ...
# Preparing to unpack .../29-r-cran-devtools_2.1.0-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-devtools (2.1.0-1cran1ppabionic0) over (2.0.2-1cran1ppabionic0) ...
# Preparing to unpack .../30-r-cran-dplyr_0.8.3-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-dplyr (0.8.3-1cran1ppabionic0) over (0.8.2-1cran1ppabionic0) ...
# Preparing to unpack .../31-r-cran-ellipsis_0.2.0.1-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-ellipsis (0.2.0.1-1cran1ppabionic0) over (0.2.0-1cran1ppabionic0) ...
# Preparing to unpack .../32-r-cran-vctrs_0.2.0-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-vctrs (0.2.0-1cran1ppabionic0) over (0.1.0-1cran1ppabionic0) ...
# Preparing to unpack .../33-r-cran-hms_0.5.0-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-hms (0.5.0-1cran1ppabionic0) over (0.4.2-3cran1ppa0bionic0) ...
# Preparing to unpack .../34-r-cran-haven_2.1.1-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-haven (2.1.1-1cran1ppabionic0) over (2.1.0-1cran1ppabionic0) ...
# Preparing to unpack .../35-r-cran-pillar_1.4.2-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-pillar (1.4.2-1cran1ppabionic0) over (1.4.1-1cran1ppabionic0) ...
# Preparing to unpack .../36-r-cran-rmarkdown_1.14-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-rmarkdown (1.14-1cran1ppabionic0) over (1.13-1cran1ppabionic0) ...
# Setting up libbz2-dev:amd64 (1.0.6-8.1ubuntu0.2) ...
# Setting up libzmq5:amd64 (4.2.5-1ubuntu0.2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Setting up libwavpack1:amd64 (5.1.0-2ubuntu1.4) ...
# Setting up tzdata (2019b-0ubuntu0.18.04) ...
#
# Current default time zone: 'Etc/UTC'
# Local time is now:      Thu Jul 18 13:27:57 UTC 2019.
# Universal Time is now:  Thu Jul 18 13:27:57 UTC 2019.
# Run 'dpkg-reconfigure tzdata' if you wish to change it.
#
# Setting up libglib2.0-0:amd64 (2.56.4-0ubuntu0.18.04.4) ...
# Setting up r-base-core (3.6.1-1bionic) ...
# Installing new version of config file /etc/R/Makeconf ...
# Setting up libnss3:amd64 (2:3.35-2ubuntu2.3) ...
# Setting up libzmq3-dev:amd64 (4.2.5-1ubuntu0.2) ...
# Setting up r-cran-ellipsis (0.2.0.1-1cran1ppabionic0) ...
# Setting up libdevmapper1.02.1:amd64 (2:1.02.145-4.1ubuntu3.18.04.1) ...
# Setting up r-base-dev (3.6.1-1bionic) ...
# Setting up bzip2 (1.0.6-8.1ubuntu0.2) ...
# Setting up r-cran-brew (1.0-6-3cran2ppa0bionic0) ...
# Setting up libglib2.0-data (2.56.4-0ubuntu0.18.04.4) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up udev (237-3ubuntu10.24) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of restart.
# Setting up libssl1.1:amd64 (1.1.1-1ubuntu2.1~18.04.4) ...
# Setting up systemd (237-3ubuntu10.24) ...
# Setting up r-cran-dplyr (0.8.3-1cran1ppabionic0) ...
# Setting up openssl (1.1.1-1ubuntu2.1~18.04.4) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for dbus (1.12.2-1ubuntu1.1) ...
# Setting up r-cran-rmarkdown (1.14-1cran1ppabionic0) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Setting up libglib2.0-bin (2.56.4-0ubuntu0.18.04.4) ...
# Setting up r-cran-digest (0.6.20-1cran1ppabionic0) ...
# Setting up r-cran-commonmark (1.7-1cran1ppabionic0) ...
# Setting up r-cran-praise (1.0.0-3cran2ubuntu1~ubuntu18.04.1~ppa1) ...
# Setting up r-cran-processx (3.4.0-1cran1ppabionic0) ...
# Setting up r-cran-boot (1.3-23-1cran1ppabionic0) ...
# Setting up r-recommended (3.6.1-1bionic) ...
# Setting up libglib2.0-dev-bin (2.56.4-0ubuntu0.18.04.4) ...
# Setting up systemd-sysv (237-3ubuntu10.24) ...
# Setting up r-cran-git2r (0.26.1-1cran1ppabionic0) ...
# Setting up libssl-dev:amd64 (1.1.1-1ubuntu2.1~18.04.4) ...
# Setting up r-cran-vctrs (0.2.0-1cran1ppabionic0) ...
# Setting up libglib2.0-dev:amd64 (2.56.4-0ubuntu0.18.04.4) ...
# Setting up r-cran-hms (0.5.0-1cran1ppabionic0) ...
# Setting up r-cran-usethis (1.5.1-1cran1ppabionic0) ...
# Setting up r-base (3.6.1-1bionic) ...
# Setting up r-cran-roxygen2 (6.1.1-1cran1ppabionic0) ...
# Setting up r-cran-pillar (1.4.2-1cran1ppabionic0) ...
# Setting up r-cran-testthat (2.1.1-1cran1ppabionic0) ...
# Setting up r-cran-callr (3.3.0-1cran1ppabionic0) ...
# Setting up libpam-systemd:amd64 (237-3ubuntu10.24) ...
# Setting up r-cran-devtools (2.1.0-1cran1ppabionic0) ...
# Setting up r-cran-haven (2.1.1-1cran1ppabionic0) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# gdal-bin is already the newest version (2.2.3+dfsg-2).
# python-gdal is already the newest version (2.2.3+dfsg-2).
# python3-gdal is already the newest version (2.2.3+dfsg-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.

# %% [markdown]
# ## Installing python packages
# The Colab environment already has many common python packages pre-installed. However, we need to install a couple more packages. We'll use `pip`, the python package installer. Again, we use the `!` notation to make a command-line call.
#
# We will install the following additional packages:
# - geopandas: a package for working with geo-spatial information (GIS)

# %%
# !apt install gdal-bin python-gdal python3-gdal
# !pip install geopandas

# %% [markdown]
# Let's test if everything worked.
#
# `cat` is a unix program (short for con _cat_ enate) which concatenates two files together. It can also be used to print the contents out to command line

# %%
import gdal
import numpy as np 
import cv2

# %%
cv2.__version__
# Out:
# '3.4.3'

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
cd gdrive
# Out:
# [Errno 2] No such file or directory: 'gdrive'
# /gdrive

# %%
gdal.Translate('band1.jpg', 'p040r30_5t19880821_nn1.tif', options = '-of JPEG')
# Out:
# <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x7f948e471f90> >

# %%
cd 'My Drive'
# Out:
# /gdrive/My Drive

# %%
ls

# %%
gdal.Translate('band2.jpg', 'p040r30_5t19880821_nn2.tif', options = '-of JPEG')
# Out:
# <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x7f948e471c00> >

# %%
gdal.Translate('band3.jpg', 'p040r30_5t19880821_nn3.tif', options = '-of JPEG')
# Out:
# <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x7f948e471f30> >

# %%
gdal.Translate('band4.jpg', 'p040r30_5t19880821_nn4.tif', options = '-of JPEG')
# Out:
# <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x7f948e471ea0> >

# %%
import numpy as np

# %%
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("band3.jpg")
blue = img[:,:,0].copy()
img = cv2.imread("band1.jpg")
green = img[:,:,0].copy()
img = cv2.imread("band2.jpg")
red = img[:,:,0].copy()
img = cv2.merge((blue,green,red))
#cv2_imshow(get_channel(im, 0))
plt.imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite("rgbImag.jpg", img)
# Out:
# True

# %%
img = cv2.imread("band3.jpg", 0)
rows, cols = img.shape

M = cv2.getRotationMatrix2D((cols/2,rows/2),12,1)
dst = cv2.warpAffine(img,M,(cols,rows))
plt.imshow(dst)

# %%
img = cv2.imread("rgmImag.jpg")

# %%
plt.imshow(img)

# %%
img = cv2.imread('band1.jpg', cv2.IMREAD_UNCHANGED)
scale_percent = 10.0
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (width, height)
# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=L size=757x715 at 0x7F948E19F4E0>

# %%
hist,bins = np.histogram(img.flatten(),256,[0,256])

#cdf = hist.cumsum()
#cdf_normalized = cdf * hist.max()/ cdf.max()

#plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.ylim([1,1e6])
#plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
img = cv2.imread('band2.jpg', cv2.IMREAD_UNCHANGED)
scale_percent = 10.0
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (width, height)
# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=L size=757x715 at 0x7F94A51D8048>

# %%
hist,bins = np.histogram(img.flatten(),256,[0,256])

#cdf = hist.cumsum()
#cdf_normalized = cdf * hist.max()/ cdf.max()

#plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.ylim([1,1e6])
#plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
img = cv2.imread('band3.jpg', cv2.IMREAD_UNCHANGED)
scale_percent = 10.0
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (width, height)
# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=L size=757x715 at 0x7F948AE6BD68>

# %%
hist,bins = np.histogram(img.flatten(),256,[0,256])

#cdf = hist.cumsum()
#cdf_normalized = cdf * hist.max()/ cdf.max()

#plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([1,256])
plt.ylim([0, 1.5e6])
#plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
b = cv2.imread('band1.jpg', 0)
g = cv2.imread('band2.jpg', 0)
r = cv2.imread('band3.jpg', 0)

"""Create a blank image that has three channels 
and the same number of pixels as your original input"""
rgb_img = np.zeros((b.shape[0], b.shape[1], 3))

"""Add the channels to the needed image one by one"""
rgb_img[:,:,0] = b
rgb_img[:,:,1] = g
rgb_img[:,:,2] = r

"""Save the needed multi channel image"""
cv2.imwrite('rgb_img.jpg',rgb_img)
# Out:
# True

# %%
img = cv2.imread('rgb_img.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)

# %%
cv2.destroyAllWindows()

# %%
cv2_imshow(rgb_img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
